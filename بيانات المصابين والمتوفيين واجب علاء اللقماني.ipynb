# %%
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
pd.read_excel(r"C:\Users\a\Desktop\معسكر علم البيانات\تدريب\deaths_1439.xlsx")
df_deaths=pd.read_excel(r"C:\Users\a\Desktop\معسكر علم البيانات\تدريب\deaths_1439.xlsx")
df_deaths

pd.read_excel(r"C:\Users\a\Desktop\معسكر علم البيانات\تدريب\Injured_1439.xlsx")
df_Injured=pd.read_excel(r"C:\Users\a\Desktop\معسكر علم البيانات\تدريب\Injured_1439.xlsx")
df_Injured
# Out:
#          الشهر                                 المنطقة   ذكور  أناث  المجموع  \
# 0         محرم  الرياض- عدد الأشخاص المصابين حسب الجنس  364.0  29.0    393.0
# 1          صفر  الرياض- عدد الأشخاص المصابين حسب الجنس  387.0  46.0    433.0
# 2     ربيع أول  الرياض- عدد الأشخاص المصابين حسب الجنس  361.0  94.0    455.0
# 3    ربيع ثانى  الرياض- عدد الأشخاص المصابين حسب الجنس  378.0  49.0    427.0
# 4    جمادى أول  الرياض- عدد الأشخاص المصابين حسب الجنس  311.0  47.0    358.0
# ..         ...                                     ...    ...   ...      ...
# 191      شعبان                                 القريات   21.0   1.0     22.0
# 192      رمضان                                 القريات   30.0   9.0     39.0
# 193       شوال                                 القريات   15.0   1.0     16.0
# 194  ذى القعدة                                 القريات   19.0   0.0     19.0
# 195   ذى الحجة                                 القريات   20.0   2.0     22.0
#
# ...

# %%
df_Injured.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   الشهر         192 non-null    object
#  1   المنطقة       192 non-null    object
#  2   ذكور          192 non-null    float64
#  3   أناث          192 non-null    float64
#  4   المجموع       192 non-null    float64
#  5   داخل المدينه  192 non-null    float64
#  6   خارج المدينه  192 non-null    float64
#  7   المجموع.1     192 non-null    float64
#  8   أقل من 18     192 non-null    float64
#  9   من18 إلى 30   192 non-null    float64
#  10  من 30 على 40  192 non-null    float64
#  11  من40إلى50     192 non-null    float64
#  12  من50فأكثر     192 non-null    float64
#  13  المجموع.2     192 non-null    float64
#  14  سعودى         192 non-null    float64
#  15  غير سعودى     192 non-null    float64
#  16  المجموع.3     192 non-null    float64
# dtypes: float64(15), object(2)
# ...

# %%
 df_deaths.info()#يوضح ان الشهر فيه 192 خانه والبقية توجد 194 وهذا يوضح انه فيه نقص في خانة الاشهر
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   الشهر         192 non-null    object
#  1   المنطقة       192 non-null    object
#  2   ذكور          194 non-null    float64
#  3   أناث          194 non-null    float64
#  4   المجموع       194 non-null    float64
#  5   داخل المدينه  194 non-null    float64
#  6   خارج المدينه  194 non-null    float64
#  7   المجموع.1     194 non-null    float64
#  8   أقل من 18     194 non-null    float64
#  9   من18 إلى 30   194 non-null    float64
#  10  من 30 على 40  194 non-null    float64
#  11  من40إلى50     194 non-null    float64
#  12  من50فأكثر     194 non-null    float64
#  13  المجموع.2     194 non-null    float64
#  14  سعودى         194 non-null    float64
#  15  غير سعودى     194 non-null    float64
#  16  المجموع.3     194 non-null    float64
# dtypes: float64(15), object(2)
# ...

# %%
df_Injured.shape#يوضح عدد العواميد والصفوف
# Out:
# (196, 17)

# %%
df_Injured.describe()#يعطي وصف للجدول المطلوب وفي مثالنا للجدول المصابين
# Out:
#              ذكور        أناث     المجموع  داخل المدينه  خارج المدينه  \
# count  192.000000  192.000000  192.000000    192.000000    192.000000
# mean   131.843750   25.536458  157.380208     78.005208     79.375000
# std     94.417956   22.501628  112.531816     75.757570     59.566629
# min     11.000000    0.000000   14.000000      0.000000      6.000000
# 25%     50.500000    6.000000   59.250000     16.750000     27.000000
# 50%    116.500000   18.000000  136.000000     50.000000     61.500000
# 75%    200.250000   41.000000  242.000000    111.500000    129.250000
# max    387.000000   94.000000  455.000000    295.000000    280.000000
#
#         المجموع.1   أقل من 18  من18 إلى 30  من 30 على 40   من40إلى50  \
# count  192.000000  192.000000   192.000000    192.000000  192.000000
# mean   157.380208   22.598958    48.500000     41.671875   27.260417
# std    112.531816   21.290821    32.999603     31.867554   24.580350
# ...

# %%
# عدد الخانات في جدول 192 
#متوسط اصابة الاناث 25.53  متوسط المصابين من الذكور  اصابة131.8
# يتضح انه اصابة الذكور اكثر من الأناث ونسبة الاصابة ما يقارب 83% والاناث ما يقارب17%من الاصابة 
# نلاحظ انه متوسط الاصابة خارج المدينة 79.3 وداخل المدينه 78 وهذا يدل ان الحوادث خارج المدينه اكثر 
#تبلغ نسبة اصابة الفئة العمرية من 18الى30 يقارب 30% واقل نسبة هي الفئة العمرية اكثرمن 50 سنه وتبلغ النسبة ما يقارب 10% من الاصابة
#  متوسط الحوادث الي اقل من 18 =22 و اكثر من 18 الى 30 = 48.5 وأكثرمن 30 الى 40 -=31.8 وأكثرمن 50 = 24.5 من وهذا يدل انه اكثر الاصابة من بين 18و30
#اقل اصابة للرجال هو 11 وكثر اصابة للرجال 387 والنساء اقل قيمة 0 واكثر قيمة 94
#اقل اصابة هي 0 من الفئة اقل من 18 ومن30الى 40 ومن 40 الى 50 
# اكثر اصابة من الفئة العمرية من 18 الى 30 وهي 132

# %%
df_Injured.isnull().sum() # يظهر عدد nullفي جدول
# Out:
# الشهر           4
# المنطقة         4
# ذكور            4
# أناث            4
# المجموع         4
# داخل المدينه    4
# خارج المدينه    4
# المجموع.1       4
# أقل من 18       4
# من18 إلى 30     4
# من 30 على 40    4
# من40إلى50       4
# من50فأكثر       4
# المجموع.2       4
# سعودى           4
# غير سعودى       4
# المجموع.3       4
# dtype: int64

# %%
df_Injured.head()
# Out:
#        الشهر                                 المنطقة   ذكور  أناث  المجموع  \
# 0       محرم  الرياض- عدد الأشخاص المصابين حسب الجنس  364.0  29.0    393.0
# 1        صفر  الرياض- عدد الأشخاص المصابين حسب الجنس  387.0  46.0    433.0
# 2   ربيع أول  الرياض- عدد الأشخاص المصابين حسب الجنس  361.0  94.0    455.0
# 3  ربيع ثانى  الرياض- عدد الأشخاص المصابين حسب الجنس  378.0  49.0    427.0
# 4  جمادى أول  الرياض- عدد الأشخاص المصابين حسب الجنس  311.0  47.0    358.0
#
#    داخل المدينه  خارج المدينه  المجموع.1  أقل من 18  من18 إلى 30  \
# 0         291.0         102.0      393.0       66.0         97.0
# 1         276.0         157.0      433.0       44.0        117.0
# 2         284.0         171.0      455.0      115.0        124.0
# 3         295.0         132.0      427.0      132.0        119.0
# 4         262.0          96.0      358.0       61.0        111.0
#
#    من 30 على 40  من40إلى50  من50فأكثر  المجموع.2  سعودى  غير سعودى  المجموع.3
# ...

# %%
df_Inj_clean = df_Injured.drop(["المجموع.1","المجموع.2","المجموع.3","المجموع"],axis=1)#حذف العامود الذي لا نرغب فيه
df_Inj_clean.head()
# Out:
#        الشهر                                 المنطقة   ذكور  أناث  \
# 0       محرم  الرياض- عدد الأشخاص المصابين حسب الجنس  364.0  29.0
# 1        صفر  الرياض- عدد الأشخاص المصابين حسب الجنس  387.0  46.0
# 2   ربيع أول  الرياض- عدد الأشخاص المصابين حسب الجنس  361.0  94.0
# 3  ربيع ثانى  الرياض- عدد الأشخاص المصابين حسب الجنس  378.0  49.0
# 4  جمادى أول  الرياض- عدد الأشخاص المصابين حسب الجنس  311.0  47.0
#
#    داخل المدينه  خارج المدينه  أقل من 18  من18 إلى 30  من 30 على 40  \
# 0         291.0         102.0       66.0         97.0         126.0
# 1         276.0         157.0       44.0        117.0         145.0
# 2         284.0         171.0      115.0        124.0         108.0
# 3         295.0         132.0      132.0        119.0         103.0
# 4         262.0          96.0       61.0        111.0          89.0
#
#    من40إلى50  من50فأكثر  سعودى  غير سعودى
# 0       73.0       31.0  213.0      180.0
# 1       79.0       48.0  271.0      162.0
# ...

# %%
df_Inj_clean.dropna(inplace=True)#حذف الصفوف التي فيها قيمة فاضية
df_Inj_clean
# Out:
#          الشهر                                 المنطقة   ذكور  أناث  \
# 0         محرم  الرياض- عدد الأشخاص المصابين حسب الجنس  364.0  29.0
# 1          صفر  الرياض- عدد الأشخاص المصابين حسب الجنس  387.0  46.0
# 2     ربيع أول  الرياض- عدد الأشخاص المصابين حسب الجنس  361.0  94.0
# 3    ربيع ثانى  الرياض- عدد الأشخاص المصابين حسب الجنس  378.0  49.0
# 4    جمادى أول  الرياض- عدد الأشخاص المصابين حسب الجنس  311.0  47.0
# ..         ...                                     ...    ...   ...
# 191      شعبان                                 القريات   21.0   1.0
# 192      رمضان                                 القريات   30.0   9.0
# 193       شوال                                 القريات   15.0   1.0
# 194  ذى القعدة                                 القريات   19.0   0.0
# 195   ذى الحجة                                 القريات   20.0   2.0
#
#      داخل المدينه  خارج المدينه  أقل من 18  من18 إلى 30  من 30 على 40  \
# 0           291.0         102.0       66.0         97.0         126.0
# ...

# %%
df_Inj_clean['ذكور'].max() #اكبرقيمة
# Out:
# 387.0

# %%
df_Inj_clean['ذكور'].min()# اقل قيمة
# Out:
# 11.0

# %%
df_Inj_clean.rename(columns={"أناث":"Female",
                             "ذكور":"Male",
                             "خارج المدينه":"outside the city","داخل المدينه":"Inside the city",
                             "أقل من 18":"Under 18","من 30 على 40":"From 30 to 40","من18 إلى 30":"From 18 to 30","من40إلى50":"From 40 to 50","من50فأكثر":"More than 50",
                             "سعودى":"Saudi","غير سعودى":"Non-Saudi","الشهر":"the month","المنطقة":"Region"},inplace=True)
#تغير اسماء عامود
df_Inj_clean.head()
# Out:
#    the month                                  Region   Male  Female  \
# 0       محرم  الرياض- عدد الأشخاص المصابين حسب الجنس  364.0    29.0
# 1        صفر  الرياض- عدد الأشخاص المصابين حسب الجنس  387.0    46.0
# 2   ربيع أول  الرياض- عدد الأشخاص المصابين حسب الجنس  361.0    94.0
# 3  ربيع ثانى  الرياض- عدد الأشخاص المصابين حسب الجنس  378.0    49.0
# 4  جمادى أول  الرياض- عدد الأشخاص المصابين حسب الجنس  311.0    47.0
#
#    Inside the city  outside the city  Under 18  From 18 to 30  From 30 to 40  \
# 0            291.0             102.0      66.0           97.0          126.0
# 1            276.0             157.0      44.0          117.0          145.0
# 2            284.0             171.0     115.0          124.0          108.0
# 3            295.0             132.0     132.0          119.0          103.0
# 4            262.0              96.0      61.0          111.0           89.0
#
#    From 40 to 50  More than 50  Saudi  Non-Saudi
# ...

# %%
df_Inj_clean.loc[df_Inj_clean["Male"]== 387.0]
#يعرض البيانات التي قيمتها
# Out:
#   the month                                  Region   Male  Female  \
# 1       صفر  الرياض- عدد الأشخاص المصابين حسب الجنس  387.0    46.0
#
#    Inside the city  outside the city  Under 18  From 18 to 30  From 30 to 40  \
# 1            276.0             157.0      44.0          117.0          145.0
#
#    From 40 to 50  More than 50  Saudi  Non-Saudi
# 1           79.0          48.0  271.0      162.0

# %%
df_Inj_clean.sample(10)

# عرض البيانات المصابين بشكل عشوائي
# Out:
#       the month                                  Region   Male  Female  \
# 147   ربيع ثانى                                     جده  207.0    21.0
# 184        محرم                                 القريات   24.0     3.0
# 113  جمادى ثانى                                  الباحه   64.0     3.0
# 193        شوال                                 القريات   15.0     1.0
# 178         رجب                                 العاصمه  308.0    67.0
# 5    جمادى ثانى  الرياض- عدد الأشخاص المصابين حسب الجنس  321.0    58.0
# 68        رمضان                                   الجوف   25.0     1.0
# 110    ربيع أول                                  الباحه   52.0    15.0
# 172        محرم                                 العاصمه  189.0    46.0
# 125  جمادى ثانى                                    عسير  128.0    34.0
#
#      Inside the city  outside the city  Under 18  From 18 to 30  \
# 147            168.0              60.0      16.0           79.0
# ...

# %%
df_Inj_clean["Region"].unique()
# Out:
# array(['الرياض- عدد الأشخاص المصابين حسب الجنس',
#        'المدينه المنوره- عــد د الأشخاص المصابين حسب الجنس',
#        'الشرقيه- عــدد الأشخاص المصابين حسب الجنس',
#        'الحـــدو د الشماليه- عــدد الأشخاص المصابين حسب الجنس', 'تبوك',
#        'الجوف', 'حائل', 'نجران', 'القصيم', 'الباحه', 'عسير', 'جازان',
#        'جده', 'الطائف', 'العاصمه', 'القريات'], dtype=object)

# %%
df_Inj_clean.loc[df_Inj_clean["Region"].isnull()]
# Out:
# Empty DataFrame
# Columns: [the month, Region, Male, Female, Inside the city, outside the city, Under 18, From 18 to 30, From 30 to 40, From 40 to 50, More than 50, Saudi, Non-Saudi]
# Index: []

# %%
df_Inj_clean["Region"].replace({'الرياض- عدد الأشخاص المصابين حسب الجنس':'Riyadh', 'القريات':'Qurayyat',
                                'المدينه المنوره- عــد د الأشخاص المصابين حسب الجنس':'Madinah',
                                'الشرقيه- عــدد الأشخاص المصابين حسب الجنس':'Eastern_Province',
                                'الحـــدو د الشماليه- عــدد الأشخاص المصابين حسب الجنس':'Northern_border','تبوك':'Tabuk',
                                'الجوف':'Al-Jouf','حائل':'Hail','نجران':'Najran','القصيم':'Qassim','الباحه':'Albaha',
                                'عسير':'Assir','جازان':'Jazan','جده':'Jeddah', 'الطائف':'Taif','العاصمه':'Makkah'},inplace = True)
#اعادة تسمية المناطق للصابين
df_Inj_clean.head()
# Out:
#    the month  Region   Male  Female  Inside the city  outside the city  \
# 0       محرم  Riyadh  364.0    29.0            291.0             102.0
# 1        صفر  Riyadh  387.0    46.0            276.0             157.0
# 2   ربيع أول  Riyadh  361.0    94.0            284.0             171.0
# 3  ربيع ثانى  Riyadh  378.0    49.0            295.0             132.0
# 4  جمادى أول  Riyadh  311.0    47.0            262.0              96.0
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0      66.0           97.0          126.0           73.0          31.0  213.0
# 1      44.0          117.0          145.0           79.0          48.0  271.0
# 2     115.0          124.0          108.0           89.0          19.0  278.0
# 3     132.0          119.0          103.0           51.0          22.0  238.0
# 4      61.0          111.0           89.0           52.0          45.0  207.0
#
#    Non-Saudi
# 0      180.0
# 1      162.0
# 2      177.0
# ...

# %%
df_Inj_clean['the month'].replace({'محرم':'Muharram', 'صفر':'Safar','ربيع أول':'Rabi_Awal','ربيع ثانى':'Rabie_Thani',
                               'جمادى أول':'Jumada-Awal','جمادى ثانى':'Jumada-Thani','رجب':'Rajab','شعبان':'Shabaan',
                               'رمضان':'Ramadan','شوال':'Shawal','ذى القعدة':'Dhu-AlQadah','ذى الحجة':'Dhul-Hijjah'},
                                inplace = True)
#اعادة تسمية الشهور للمصابين
df_Inj_clean.sample(10)
# Out:
#         the month            Region   Male  Female  Inside the city  \
# 189  Jumada-Thani          Qurayyat   14.0     0.0              7.0
# 92        Ramadan            Najran   38.0     6.0             11.0
# 29   Jumada-Thani  Eastern_Province  181.0    48.0            168.0
# 160      Muharram              Taif  198.0    72.0             99.0
# 75    Rabie_Thani              Hail   76.0     3.0             28.0
# 18          Rajab           Madinah  215.0    37.0            111.0
# 39    Rabie_Thani   Northern_border   35.0     7.0             16.0
# 79        Shabaan              Hail  112.0    14.0            113.0
# 171   Dhul-Hijjah              Taif  226.0    51.0            159.0
# 102         Rajab            Qassim   98.0    28.0            108.0
#
#      outside the city  Under 18  From 18 to 30  From 30 to 40  From 40 to 50  \
# 189               7.0      11.0            2.0            0.0            0.0
# ...

# %%
df_deaths.head()
# Out:
#        الشهر المنطقة  ذكور  أناث  المجموع  داخل المدينه  خارج المدينه  \
# 0       محرم  الرياض  95.0   5.0    100.0          54.0          46.0
# 1        صفر  الرياض  93.0   5.0     98.0          57.0          41.0
# 2   ربيع أول  الرياض  94.0  11.0    105.0          49.0          56.0
# 3  ربيع ثانى  الرياض  85.0   6.0     91.0          46.0          45.0
# 4  جمادى أول  الرياض  95.0   1.0     96.0          51.0          45.0
#
#    المجموع.1  أقل من 18  من18 إلى 30  من 30 على 40  من40إلى50  من50فأكثر  \
# 0      100.0        9.0         38.0          27.0       12.0       14.0
# 1       98.0        9.0         38.0          25.0       14.0       12.0
# 2      105.0       22.0         13.0          35.0       24.0       11.0
# 3       91.0       29.0         22.0          19.0       13.0        8.0
# 4       96.0       15.0         35.0          26.0       12.0        8.0
#
#    المجموع.2  سعودى  غير سعودى  المجموع.3
# 0      100.0   46.0       54.0      100.0
# ...

# %%
df_deaths_clean=df_deaths.drop(["المجموع.1","المجموع.2","المجموع.3","المجموع"],axis=1)#حذف العامود للمتوافيين
df_deaths_clean.head()
# Out:
#        الشهر المنطقة  ذكور  أناث  داخل المدينه  خارج المدينه  أقل من 18  \
# 0       محرم  الرياض  95.0   5.0          54.0          46.0        9.0
# 1        صفر  الرياض  93.0   5.0          57.0          41.0        9.0
# 2   ربيع أول  الرياض  94.0  11.0          49.0          56.0       22.0
# 3  ربيع ثانى  الرياض  85.0   6.0          46.0          45.0       29.0
# 4  جمادى أول  الرياض  95.0   1.0          51.0          45.0       15.0
#
#    من18 إلى 30  من 30 على 40  من40إلى50  من50فأكثر  سعودى  غير سعودى
# 0         38.0          27.0       12.0       14.0   46.0       54.0
# 1         38.0          25.0       14.0       12.0   46.0       52.0
# 2         13.0          35.0       24.0       11.0   59.0       46.0
# 3         22.0          19.0       13.0        8.0   49.0       42.0
# 4         35.0          26.0       12.0        8.0   52.0       44.0

# %%
df_deaths_clean.rename(columns={"أناث":"Female",
                                "ذكور":"Male",
                                "خارج المدينه":"outside the city",
                                "داخل المدينه":"Inside the city",
                                "أقل من 18":"Under 18",
                                "من 30 على 40":"From 30 to 40",
                                "من18 إلى 30":"From 18 to 30",
                                "من40إلى50":"From 40 to 50",
                                "من50فأكثر":"More than 50",
                                "سعودى":"Saudi",
                                "غير سعودى":"Non-Saudi",
                                "الشهر":"the month",
                                "المنطقة":"Region"},inplace=True) # اعادة تسمية العواميد  للمتوفيين
df_deaths_clean.head()
# Out:
#    the month  Region  Male  Female  Inside the city  outside the city  \
# 0       محرم  الرياض  95.0     5.0             54.0              46.0
# 1        صفر  الرياض  93.0     5.0             57.0              41.0
# 2   ربيع أول  الرياض  94.0    11.0             49.0              56.0
# 3  ربيع ثانى  الرياض  85.0     6.0             46.0              45.0
# 4  جمادى أول  الرياض  95.0     1.0             51.0              45.0
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0       9.0           38.0           27.0           12.0          14.0   46.0
# 1       9.0           38.0           25.0           14.0          12.0   46.0
# 2      22.0           13.0           35.0           24.0          11.0   59.0
# 3      29.0           22.0           19.0           13.0           8.0   49.0
# 4      15.0           35.0           26.0           12.0           8.0   52.0
#
#    Non-Saudi
# 0       54.0
# 1       52.0
# 2       46.0
# 3       42.0
# ...

# %%
df_deaths_clean.sample(20)
# Out:
#      the month                                          Region  Male  Female  \
# 55         صفر                                          تـبـوك  22.0     1.0
# 107        صفر                                          القصيم  18.0     1.0
# 127      رمضان                                          الباحه   6.0     0.0
# 117   ذى الحجة                                          القصيم  13.0     1.0
# 11    ذى الحجة                                          الرياض  93.0     7.0
# 31   ربيع ثانى                                         الشرقيه  67.0    12.0
# 110  جمادى أول                                          القصيم  26.0     1.0
# 132       محرم                                        عـــسـير  52.0     6.0
# 57   ربيع ثانى                                          تـبـوك  20.0     1.0
# 71   جمادى أول                                      الجـــــوف   5.0     0.0
# 188  جمادى أول         العاصمه- عدد الأشخاص المتوفين حسب الجنس  36.0     7.0
# ...

# %%
df_deaths_clean["Region"].unique()
# Out:
# array(['الرياض', nan, 'المدينه المنوره', 'الشرقيه', 'الحدود الشماليه',
#        'تـبـوك', 'الجـــــوف', 'حـــائل', 'نجران', 'القصيم', 'الباحه',
#        'عـــسـير', 'جازان', 'جده', 'الطائف',
#        'العاصمه- عدد الأشخاص المتوفين حسب الجنس',
#        'الـقـريات -عــد د الأشخاص المتوفين حـسب الجـنس'], dtype=object)

# %%
df_deaths_clean[df_deaths_clean["Region"].isnull()] # يظهر ال Nan
# Out:
#     the month Region   Male  Female  Inside the city  outside the city  \
# 12        NaN    NaN    NaN     NaN              NaN               NaN
# 13        NaN    NaN    NaN     NaN              NaN               NaN
# 14        NaN    NaN    NaN     NaN              NaN               NaN
# 27        NaN    NaN    NaN     NaN              NaN               NaN
# 40        NaN    NaN    NaN     NaN              NaN               NaN
# 53        NaN    NaN    NaN     NaN              NaN               NaN
# 66        NaN    NaN    NaN     NaN              NaN               NaN
# 79        NaN    NaN    NaN     NaN              NaN               NaN
# 92        NaN    NaN    NaN     NaN              NaN               NaN
# 105       NaN    NaN    NaN     NaN              NaN               NaN
# 118       NaN    NaN    NaN     NaN              NaN               NaN
# 131       NaN    NaN   98.0    13.0             67.0              44.0
# ...

# %%
df_deaths_clean.shape # يعرض عدد الصفوف والاعمدة
# Out:
# (209, 13)

# %%
df_deaths_clean.dropna(inplace=True) # حذف الصف والعواميد Nan
df_deaths_clean.shape
# Out:
# (192, 13)

# %%
df_deaths_clean["Region"].replace({'الرياض':'Riyadh', 'الـقـريات -عــد د الأشخاص المتوفين حـسب الجـنس':'Qurayyat',
                                'المدينه المنوره':'Madinah',
                                'الشرقيه':'Eastern_Province',
                                'الحدود الشماليه':'Northern_border','تـبـوك':'Tabuk',
                                'الجـــــوف':'Al-Jouf','حـــائل':'Hail','نجران':'Najran','القصيم':'Qassim','الباحه':'Albaha',
                                'عـــسـير':'Assir','جازان':'Jazan','جده':'Jeddah', 'الطائف':'Taif','العاصمه- عدد الأشخاص المتوفين حسب الجنس':'Makkah'},inplace = True)
# تغير الاسماء المدن

df_deaths_clean.head()
# Out:
#    the month  Region  Male  Female  Inside the city  outside the city  \
# 0       محرم  Riyadh  95.0     5.0             54.0              46.0
# 1        صفر  Riyadh  93.0     5.0             57.0              41.0
# 2   ربيع أول  Riyadh  94.0    11.0             49.0              56.0
# 3  ربيع ثانى  Riyadh  85.0     6.0             46.0              45.0
# 4  جمادى أول  Riyadh  95.0     1.0             51.0              45.0
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0       9.0           38.0           27.0           12.0          14.0   46.0
# 1       9.0           38.0           25.0           14.0          12.0   46.0
# 2      22.0           13.0           35.0           24.0          11.0   59.0
# 3      29.0           22.0           19.0           13.0           8.0   49.0
# 4      15.0           35.0           26.0           12.0           8.0   52.0
#
#    Non-Saudi
# 0       54.0
# 1       52.0
# 2       46.0
# 3       42.0
# ...

# %%
df_deaths_clean['the month'].replace({'محرم':'Muharram', 'صفر':'Safar','ربيع أول':'Rabi_Awal','ربيع ثانى':'Rabie_Thani',
                               'جمادى أول':'Jumada-Awal','جمادى ثانى':'Jumada-Thani','رجب':'Rajab','شعبان':'Shabaan',
                               'رمضان':'Ramadan','شوال':'Shawal','ذى القعدة':'Dhu-AlQadah','ذى الحجة':'Dhul-Hijjah'},
                                inplace = True)
df_deaths_clean.sample(10)
# Out:
#         the month   Region  Male  Female  Inside the city  outside the city  \
# 171      Muharram     Taif   9.0    19.0              3.0              25.0
# 20   Jumada-Thani  Madinah  29.0     7.0             11.0              25.0
# 178       Shabaan     Taif  24.0     9.0              6.0              27.0
# 111  Jumada-Thani   Qassim  11.0     1.0             11.0               1.0
# 154        Shawal    Jazan   3.0    40.0              4.0              39.0
# 137  Jumada-Thani    Assir  48.0     5.0              6.0              47.0
# 153       Ramadan    Jazan  35.0     4.0              7.0              32.0
# 17      Rabi_Awal  Madinah  27.0     9.0              7.0              29.0
# 142   Dhu-AlQadah    Assir  45.0     5.0              3.0              47.0
# 127       Ramadan   Albaha   6.0     0.0              2.0               4.0
#
#      Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  \
# ...

# %%
df_deaths_clean["Region"].unique()# نعرف في العامود هل فيه بيانات متكرره
# Out:
# array(['Riyadh', 'Madinah', 'Eastern_Province', 'Northern_border',
#        'Tabuk', 'Al-Jouf', 'Hail', 'Najran', 'Qassim', 'Albaha', 'Assir',
#        'Jazan', 'Jeddah', 'Taif', 'Makkah', 'Qurayyat'], dtype=object)

# %%
df_deaths_clean.isnull().sum()# اكتشف اذا كان فيه في جدول الوفيات nan
# Out:
# the month           0
# Region              0
# Male                0
# Female              0
# Inside the city     0
# outside the city    0
# Under 18            0
# From 18 to 30       0
# From 30 to 40       0
# From 40 to 50       0
# More than 50        0
# Saudi               0
# Non-Saudi           0
# dtype: int64

# %%
df_Inj_clean.isnull().sum()# الكشف اذا فيه nan في المصابين
# Out:
# the month           0
# Region              0
# Male                0
# Female              0
# Inside the city     0
# outside the city    0
# Under 18            0
# From 18 to 30       0
# From 30 to 40       0
# From 40 to 50       0
# More than 50        0
# Saudi               0
# Non-Saudi           0
# dtype: int64

# %%
df_deaths_clean.head()
# Out:
#      the month  Region  Male  Female  Inside the city  outside the city  \
# 0     Muharram  Riyadh  95.0     5.0             54.0              46.0
# 1        Safar  Riyadh  93.0     5.0             57.0              41.0
# 2    Rabi_Awal  Riyadh  94.0    11.0             49.0              56.0
# 3  Rabie_Thani  Riyadh  85.0     6.0             46.0              45.0
# 4  Jumada-Awal  Riyadh  95.0     1.0             51.0              45.0
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0       9.0           38.0           27.0           12.0          14.0   46.0
# 1       9.0           38.0           25.0           14.0          12.0   46.0
# 2      22.0           13.0           35.0           24.0          11.0   59.0
# 3      29.0           22.0           19.0           13.0           8.0   49.0
# 4      15.0           35.0           26.0           12.0           8.0   52.0
#
#    Non-Saudi
# 0       54.0
# 1       52.0
# 2       46.0
# ...

# %%
#الان نحذف الاشهر والسنة من جدول المتوفين ونظيفه في متغير جديد وذلك لكي يتم تمثيل البيانات الجدول 

df_deaths_clean_heat_map=df_deaths_clean.drop(["the month","Region"],axis=1)
df_deaths_clean_heat_map.head()
# Out:
#    Male  Female  Inside the city  outside the city  Under 18  From 18 to 30  \
# 0  95.0     5.0             54.0              46.0       9.0           38.0
# 1  93.0     5.0             57.0              41.0       9.0           38.0
# 2  94.0    11.0             49.0              56.0      22.0           13.0
# 3  85.0     6.0             46.0              45.0      29.0           22.0
# 4  95.0     1.0             51.0              45.0      15.0           35.0
#
#    From 30 to 40  From 40 to 50  More than 50  Saudi  Non-Saudi
# 0           27.0           12.0          14.0   46.0       54.0
# 1           25.0           14.0          12.0   46.0       52.0
# 2           35.0           24.0          11.0   59.0       46.0
# 3           19.0           13.0           8.0   49.0       42.0
# 4           26.0           12.0           8.0   52.0       44.0

# %%
sns.heatmap(df_deaths_clean_heat_map.corr(),annot=True)#  هذا امر اظهر الرسم البياني للمتوفيين
# Out:
# <Axes: >

# %%
#df_dea_melt=df_deaths_clean.melt(id_vars=["the month","Region"])
#df_dea_melt
#نضيف عامود يحسب النسبة المؤية للمتوفين رجال ونساء
df_deaths_percent=df_deaths_clean
df_deaths_percent["Percent of the deaths Male"]=(df_deaths_clean["Male"])/(df_deaths_clean["Male"]+df_deaths_clean["Female"])*100
df_deaths_percent["Percent of the deaths Female"]=(df_deaths_clean["Female"])/(df_deaths_clean["Male"]+df_deaths_clean["Female"])*100
df_deaths_percent.head()
# Out:
#      the month  Region  Male  Female  Inside the city  outside the city  \
# 0     Muharram  Riyadh  95.0     5.0             54.0              46.0
# 1        Safar  Riyadh  93.0     5.0             57.0              41.0
# 2    Rabi_Awal  Riyadh  94.0    11.0             49.0              56.0
# 3  Rabie_Thani  Riyadh  85.0     6.0             46.0              45.0
# 4  Jumada-Awal  Riyadh  95.0     1.0             51.0              45.0
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0       9.0           38.0           27.0           12.0          14.0   46.0
# 1       9.0           38.0           25.0           14.0          12.0   46.0
# 2      22.0           13.0           35.0           24.0          11.0   59.0
# 3      29.0           22.0           19.0           13.0           8.0   49.0
# 4      15.0           35.0           26.0           12.0           8.0   52.0
#
# ...

# %%
sns.barplot(x="Percent of the deaths Male",y="Region", errorbar=None,data=df_deaths_percent)
# Out:
# <Axes: xlabel='Percent of the deaths Male', ylabel='Region'>

# %%
#من خلال الرسم البياني يتضح انه اكثر الوفيات في منطقة القصيم

# %%
#df_dea_melt=df_deaths_clean.melt(id_vars=["Region","Percent of the deaths Male"])
#df_dea_melt
sns.histplot(df_deaths_percent,y="the month",x="Percent of the deaths Male")
# Out:
# <Axes: xlabel='Percent of the deaths Male', ylabel='the month'>

# %%
#من خلال الاشهر يتضح ان نسبة الوفيات للرجال تكثر في شهر جماد الاول و ربيع الاول وصفر

# %%
sns.barplot(x="Percent of the deaths Female",y="Region", errorbar=None,data=df_deaths_percent)
# Out:
# <Axes: xlabel='Percent of the deaths Female', ylabel='Region'>

# %%
#اكثر نسبة وفيات للنساء في المدينة المنورة

# %%
sns.histplot(df_deaths_percent,y="the month",x="Percent of the deaths Female")
# Out:
# <Axes: xlabel='Percent of the deaths Female', ylabel='the month'>

# %%
#أكثر نسبة مفيات للنساء في شهر ذي الحجة وشوال وجماد أول

# %%
df_dea_melt=df_deaths_percent.melt(id_vars=["Region","Percent of the deaths Male"])
df_dea_melt
# Out:
#         Region  Percent of the deaths Male                      variable  \
# 0       Riyadh                   95.000000                     the month
# 1       Riyadh                   94.897959                     the month
# 2       Riyadh                   89.523810                     the month
# 3       Riyadh                   93.406593                     the month
# 4       Riyadh                   98.958333                     the month
# ...        ...                         ...                           ...
# 2491  Qurayyat                         NaN  Percent of the deaths Female
# 2492  Qurayyat                   62.500000  Percent of the deaths Female
# 2493  Qurayyat                   50.000000  Percent of the deaths Female
# 2494  Qurayyat                  100.000000  Percent of the deaths Female
# 2495  Qurayyat                   75.000000  Percent of the deaths Female
#
#             value
# 0        Muharram
# 1           Safar
# 2       Rabi_Awal
# ...

# %%
#الان نحذف الاشهر والسنة من جدول المصابين ونظيفه في متغير جديد وذلك لكي يتم تمثيل البيانات الجدول
df_Inj_clean_heat_map=df_Inj_clean.drop(["the month","Region"],axis=1)
df_Inj_clean_heat_map.head()
# Out:
#     Male  Female  Inside the city  outside the city  Under 18  From 18 to 30  \
# 0  364.0    29.0            291.0             102.0      66.0           97.0
# 1  387.0    46.0            276.0             157.0      44.0          117.0
# 2  361.0    94.0            284.0             171.0     115.0          124.0
# 3  378.0    49.0            295.0             132.0     132.0          119.0
# 4  311.0    47.0            262.0              96.0      61.0          111.0
#
#    From 30 to 40  From 40 to 50  More than 50  Saudi  Non-Saudi
# 0          126.0           73.0          31.0  213.0      180.0
# 1          145.0           79.0          48.0  271.0      162.0
# 2          108.0           89.0          19.0  278.0      177.0
# 3          103.0           51.0          22.0  238.0      189.0
# 4           89.0           52.0          45.0  207.0      151.0

# %%
sns.heatmap(df_Inj_clean_heat_map.corr(),annot=True)#  الان نرسم البيانات للمصابين
# Out:
# <Axes: >

# %%
df_Inj_percent=df_deaths_clean
df_Inj_percent["Percent of the Inj Male"]=(df_Inj_clean["Male"])/(df_Inj_clean["Male"]+df_Inj_clean["Female"])*100
df_Inj_percent["Percent of the Inj Female"]=(df_Inj_clean["Female"])/(df_Inj_clean["Male"]+df_Inj_clean["Female"])*100
df_Inj_percent.head()
# Out:
#      the month  Region  Male  Female  Inside the city  outside the city  \
# 0     Muharram  Riyadh  95.0     5.0             54.0              46.0
# 1        Safar  Riyadh  93.0     5.0             57.0              41.0
# 2    Rabi_Awal  Riyadh  94.0    11.0             49.0              56.0
# 3  Rabie_Thani  Riyadh  85.0     6.0             46.0              45.0
# 4  Jumada-Awal  Riyadh  95.0     1.0             51.0              45.0
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0       9.0           38.0           27.0           12.0          14.0   46.0
# 1       9.0           38.0           25.0           14.0          12.0   46.0
# 2      22.0           13.0           35.0           24.0          11.0   59.0
# 3      29.0           22.0           19.0           13.0           8.0   49.0
# 4      15.0           35.0           26.0           12.0           8.0   52.0
#
# ...

# %%
sns.barplot(x="Percent of the Inj Male",y="Region", errorbar=None,data=df_Inj_percent)
# Out:
# <Axes: xlabel='Percent of the Inj Male', ylabel='Region'>

# %%
# نسبة الاصبات الرجال في مكة المكرمة

# %%
sns.histplot(df_deaths_percent,y="the month",x="Percent of the Inj Male")
# Out:
# <Axes: xlabel='Percent of the Inj Male', ylabel='the month'>

# %%
#اكثر الشهور التي يحدث فيها اصابات رجال في شهر محرم

# %%
sns.barplot(x="Percent of the Inj Female",y="Region", errorbar=None,data=df_Inj_percent)
# Out:
# <Axes: xlabel='Percent of the Inj Female', ylabel='Region'>

# %%
# اكثر اصابات للنساء في المدينة المنورة

# %%
sns.histplot(df_deaths_percent,y="the month",x="Percent of the Inj Female")
# Out:
# <Axes: xlabel='Percent of the Inj Female', ylabel='the month'>

# %%
#من اكثر شهور الاصبات للنساء في ربيع اول

# %%
df_deaths_clean.to_excel(r"C:\Users\a\Desktop\new.xlsx")#تم حفظ البيانات في الاكسل

# %%
df_deaths_clean[df_deaths_clean["From 18 to 30"]==40.000000]
# Out:
#   the month  Region  Male  Female  Inside the city  outside the city  \
# 9    Shawal  Riyadh  92.0     8.0             52.0              48.0
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 9      21.0           40.0           19.0           15.0           5.0   55.0
#
#    Non-Saudi  Percent of the deaths Male  Percent of the deaths Female  \
# 9       45.0                        92.0                           8.0
#
#    Percent of the Inj Male  Percent of the Inj Female
# 9                  85.9375                    14.0625

# %%
df_Inj_clean.head()
# Out:
#      the month  Region   Male  Female  Inside the city  outside the city  \
# 0     Muharram  Riyadh  364.0    29.0            291.0             102.0
# 1        Safar  Riyadh  387.0    46.0            276.0             157.0
# 2    Rabi_Awal  Riyadh  361.0    94.0            284.0             171.0
# 3  Rabie_Thani  Riyadh  378.0    49.0            295.0             132.0
# 4  Jumada-Awal  Riyadh  311.0    47.0            262.0              96.0
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0      66.0           97.0          126.0           73.0          31.0  213.0
# 1      44.0          117.0          145.0           79.0          48.0  271.0
# 2     115.0          124.0          108.0           89.0          19.0  278.0
# 3     132.0          119.0          103.0           51.0          22.0  238.0
# 4      61.0          111.0           89.0           52.0          45.0  207.0
#
#    Non-Saudi
# 0      180.0
# 1      162.0
# 2      177.0
# ...

# %%
df_deaths_clean.columns # نراجع اسماء عواميد المتوفين
# Out:
# Index(['the month', 'Region', 'Male', 'Female', 'Inside the city',
#        'outside the city', 'Under 18', 'From 18 to 30', 'From 30 to 40',
#        'From 40 to 50', 'More than 50', 'Saudi', 'Non-Saudi',
#        'Percent of the deaths Male', 'Percent of the deaths Female',
#        'Percent of the Inj Male', 'Percent of the Inj Female'],
#       dtype='object')

# %%
df_Inj_clean.columns # نراجع اسماء عواميد المصابين
# Out:
# Index(['the month', 'Region', 'Male', 'Female', 'Inside the city',
#        'outside the city', 'Under 18', 'From 18 to 30', 'From 30 to 40',
#        'From 40 to 50', 'More than 50', 'Saudi', 'Non-Saudi'],
#       dtype='object')

# %%
#df_deaths_clean_W=df_deaths_clean.pivot_table(index=["Region",'the month'])# لعرض البيانات بالعرض
df_deaths_clean_W=df_deaths_clean
df_deaths_clean_W
# Out:
#        the month    Region  Male  Female  Inside the city  outside the city  \
# 0       Muharram    Riyadh  95.0     5.0             54.0              46.0
# 1          Safar    Riyadh  93.0     5.0             57.0              41.0
# 2      Rabi_Awal    Riyadh  94.0    11.0             49.0              56.0
# 3    Rabie_Thani    Riyadh  85.0     6.0             46.0              45.0
# 4    Jumada-Awal    Riyadh  95.0     1.0             51.0              45.0
# ..           ...       ...   ...     ...              ...               ...
# 204      Shabaan  Qurayyat   0.0     0.0              0.0               0.0
# 205      Ramadan  Qurayyat   5.0     3.0              0.0               8.0
# 206       Shawal  Qurayyat   1.0     1.0              0.0               2.0
# 207  Dhu-AlQadah  Qurayyat   4.0     0.0              0.0               4.0
# 208  Dhul-Hijjah  Qurayyat   6.0     2.0              0.0               8.0
#
# ...

# %%
#df_Inj_clean_W=df_Inj_clean.pivot_table(index=["Region","the month"])
df_Inj_clean_W=df_Inj_clean
df_Inj_clean_W.head()
# Out:
#      the month  Region   Male  Female  Inside the city  outside the city  \
# 0     Muharram  Riyadh  364.0    29.0            291.0             102.0
# 1        Safar  Riyadh  387.0    46.0            276.0             157.0
# 2    Rabi_Awal  Riyadh  361.0    94.0            284.0             171.0
# 3  Rabie_Thani  Riyadh  378.0    49.0            295.0             132.0
# 4  Jumada-Awal  Riyadh  311.0    47.0            262.0              96.0
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0      66.0           97.0          126.0           73.0          31.0  213.0
# 1      44.0          117.0          145.0           79.0          48.0  271.0
# 2     115.0          124.0          108.0           89.0          19.0  278.0
# 3     132.0          119.0          103.0           51.0          22.0  238.0
# 4      61.0          111.0           89.0           52.0          45.0  207.0
#
#    Non-Saudi
# 0      180.0
# 1      162.0
# 2      177.0
# ...

# %%
#df2=df_Inj_clean.melt(id_vars=['Region','the month'])
#df2

# %%
#df_male=df2[df2['variable']=='Male']
#df_female=df2[df2['variable']=='Female']
#df_female

# %%
df_dea_And_Inj=pd.merge(df_deaths_clean_W,df_Inj_clean_W,on=["Region","the month"],how="left")
df_dea_And_Inj
# Out:
#        the month    Region  Male_x  Female_x  Inside the city_x  \
# 0       Muharram    Riyadh    95.0       5.0               54.0
# 1          Safar    Riyadh    93.0       5.0               57.0
# 2      Rabi_Awal    Riyadh    94.0      11.0               49.0
# 3    Rabie_Thani    Riyadh    85.0       6.0               46.0
# 4    Jumada-Awal    Riyadh    95.0       1.0               51.0
# ..           ...       ...     ...       ...                ...
# 187      Shabaan  Qurayyat     0.0       0.0                0.0
# 188      Ramadan  Qurayyat     5.0       3.0                0.0
# 189       Shawal  Qurayyat     1.0       1.0                0.0
# 190  Dhu-AlQadah  Qurayyat     4.0       0.0                0.0
# 191  Dhul-Hijjah  Qurayyat     6.0       2.0                0.0
#
#      outside the city_x  Under 18_x  From 18 to 30_x  From 30 to 40_x  \
# 0                  46.0         9.0             38.0             27.0
# ...

# %%
df_dea_And_Inj.isnull().sum()
# Out:
# the month                        0
# Region                           0
# Male_x                           0
# Female_x                         0
# Inside the city_x                0
# outside the city_x               0
# Under 18_x                       0
# From 18 to 30_x                  0
# From 30 to 40_x                  0
# From 40 to 50_x                  0
# More than 50_x                   0
# Saudi_x                          0
# Non-Saudi_x                      0
# Percent of the deaths Male       3
# Percent of the deaths Female     3
# Percent of the Inj Male         15
# Percent of the Inj Female       15
# Male_y                           3
# Female_y                         3
# Inside the city_y                3
# outside the city_y               3
# Under 18_y                       3
# From 18 to 30_y                  3
# From 30 to 40_y                  3
# From 40 to 50_y                  3
# More than 50_y                   3
# Saudi_y                          3
# ...

# %%
df_dea_And_Inj[df_dea_And_Inj["Percent of the Inj Male"].isnull()]#
# Out:
#         the month    Region  Male_x  Female_x  Inside the city_x  \
# 143   Dhul-Hijjah     Jazan    49.0       1.0                6.0
# 144      Muharram    Jeddah    27.0       4.0               22.0
# 145         Safar    Jeddah    27.0       5.0               12.0
# 180      Muharram  Qurayyat     0.0       0.0                0.0
# 181         Safar  Qurayyat    12.0       1.0                3.0
# 182     Rabi_Awal  Qurayyat     8.0       1.0                1.0
# 183   Rabie_Thani  Qurayyat     2.0       0.0                1.0
# 184   Jumada-Awal  Qurayyat     4.0       0.0                1.0
# 185  Jumada-Thani  Qurayyat     0.0       0.0                0.0
# 186         Rajab  Qurayyat     5.0       0.0                2.0
# 187       Shabaan  Qurayyat     0.0       0.0                0.0
# 188       Ramadan  Qurayyat     5.0       3.0                0.0
# 189        Shawal  Qurayyat     1.0       1.0                0.0
# ...

# %%
df_dea_And_Inj.dropna(inplace=True) # حذف الصف والعواميد بعد عملية الدمج Nan
df_dea_And_Inj.shape
# Out:
# (174, 28)

# %%
df_dea_And_Inj.isnull().sum()
# Out:
# the month                       0
# Region                          0
# Male_x                          0
# Female_x                        0
# Inside the city_x               0
# outside the city_x              0
# Under 18_x                      0
# From 18 to 30_x                 0
# From 30 to 40_x                 0
# From 40 to 50_x                 0
# More than 50_x                  0
# Saudi_x                         0
# Non-Saudi_x                     0
# Percent of the deaths Male      0
# Percent of the deaths Female    0
# Percent of the Inj Male         0
# Percent of the Inj Female       0
# Male_y                          0
# Female_y                        0
# Inside the city_y               0
# outside the city_y              0
# Under 18_y                      0
# From 18 to 30_y                 0
# From 30 to 40_y                 0
# From 40 to 50_y                 0
# More than 50_y                  0
# Saudi_y                         0
# ...

# %%
df_dea_And_Inj.describe().transpose()# استعرضنا وصف للبيانات بعد عملية الدمج بين جدول المصابين وجدول المتوفيين
# Out:
#                               count        mean        std        min  \
# Male_x                        174.0   28.712644  22.504159   2.000000
# Female_x                      174.0    4.011494   4.612108   0.000000
# Inside the city_x             174.0   10.913793  11.225412   0.000000
# outside the city_x            174.0   21.810345  17.332308   0.000000
# Under 18_x                    174.0    4.505747   5.126997   0.000000
# From 18 to 30_x               174.0   10.574713   8.786001   0.000000
# From 30 to 40_x               174.0    7.839080   6.425875   0.000000
# From 40 to 50_x               174.0    4.574713   4.124177   0.000000
# More than 50_x                174.0    5.229885   5.442715   0.000000
# Saudi_x                       174.0   19.862069  14.167187   1.000000
# Non-Saudi_x                   174.0   12.862069  12.541420   0.000000
# Percent of the deaths Male    174.0   87.628100  12.199206   6.976744
# ...

# %%
df_dea_And_Inj.columns
# Out:
# Index(['the month', 'Region', 'Male_x', 'Female_x', 'Inside the city_x',
#        'outside the city_x', 'Under 18_x', 'From 18 to 30_x',
#        'From 30 to 40_x', 'From 40 to 50_x', 'More than 50_x', 'Saudi_x',
#        'Non-Saudi_x', 'Percent of the deaths Male',
#        'Percent of the deaths Female', 'Percent of the Inj Male',
#        'Percent of the Inj Female', 'Male_y', 'Female_y', 'Inside the city_y',
#        'outside the city_y', 'Under 18_y', 'From 18 to 30_y',
#        'From 30 to 40_y', 'From 40 to 50_y', 'More than 50_y', 'Saudi_y',
#        'Non-Saudi_y'],
#       dtype='object')

# %%
df_dea_And_Inj["Total accidents"]=df_dea_And_Inj["Female_x"]+df_dea_And_Inj["Male_x"]+df_dea_And_Inj["Male_y"]+df_dea_And_Inj["Female_y"]
df_dea_And_Inj.head()

#نقوم بحساب عدد الحوادث
# Out:
#      the month  Region  Male_x  Female_x  Inside the city_x  \
# 0     Muharram  Riyadh    95.0       5.0               54.0
# 1        Safar  Riyadh    93.0       5.0               57.0
# 2    Rabi_Awal  Riyadh    94.0      11.0               49.0
# 3  Rabie_Thani  Riyadh    85.0       6.0               46.0
# 4  Jumada-Awal  Riyadh    95.0       1.0               51.0
#
#    outside the city_x  Under 18_x  From 18 to 30_x  From 30 to 40_x  \
# 0                46.0         9.0             38.0             27.0
# 1                41.0         9.0             38.0             25.0
# 2                56.0        22.0             13.0             35.0
# 3                45.0        29.0             22.0             19.0
# 4                45.0        15.0             35.0             26.0
#
#    From 40 to 50_x  ...  Inside the city_y  outside the city_y  Under 18_y  \
# 0             12.0  ...              291.0               102.0        66.0
# ...

# %%
sns.barplot(x="Total accidents",y="Region", errorbar=None,data=df_dea_And_Inj)
# Out:
# <Axes: xlabel='Total accidents', ylabel='Region'>

# %%
sns.barplot(x="Total accidents",y="the month", errorbar=None,data=df_dea_And_Inj)
# Out:
# <Axes: xlabel='Total accidents', ylabel='the month'>

# %%
# من خلال ما قمنا بعملية الدمج بين جدول الوفيات والاصابات اتضح انه اكثر منطقة حوادث هي الرياض
# واكثر شهر يحدث فيه الحوادث خلال شهر رمضان المبارك

# %%
df3=df_dea_And_Inj.melt(id_vars=["Region","the month"])
df3
# Out:
#       Region    the month         variable  value
# 0     Riyadh     Muharram           Male_x   95.0
# 1     Riyadh        Safar           Male_x   93.0
# 2     Riyadh    Rabi_Awal           Male_x   94.0
# 3     Riyadh  Rabie_Thani           Male_x   85.0
# 4     Riyadh  Jumada-Awal           Male_x   95.0
# ...      ...          ...              ...    ...
# 4693  Makkah      Shabaan  Total accidents  299.0
# 4694  Makkah      Ramadan  Total accidents  470.0
# 4695  Makkah       Shawal  Total accidents  340.0
# 4696  Makkah  Dhu-AlQadah  Total accidents  295.0
# 4697  Makkah  Dhul-Hijjah  Total accidents  397.0
#
# [4698 rows x 4 columns]

# %%
df_dea_And_Inj.describe().transpose()
# Out:
#                               count        mean         std        min  \
# Male_x                        174.0   28.712644   22.504159   2.000000
# Female_x                      174.0    4.011494    4.612108   0.000000
# Inside the city_x             174.0   10.913793   11.225412   0.000000
# outside the city_x            174.0   21.810345   17.332308   0.000000
# Under 18_x                    174.0    4.505747    5.126997   0.000000
# From 18 to 30_x               174.0   10.574713    8.786001   0.000000
# From 30 to 40_x               174.0    7.839080    6.425875   0.000000
# From 40 to 50_x               174.0    4.574713    4.124177   0.000000
# More than 50_x                174.0    5.229885    5.442715   0.000000
# Saudi_x                       174.0   19.862069   14.167187   1.000000
# Non-Saudi_x                   174.0   12.862069   12.541420   0.000000
# Percent of the deaths Male    174.0   87.628100   12.199206   6.976744
# ...

# %%
df_dea_And_Inj_W=df_dea_And_Inj.pivot_table(index=["Region","the month"])
df_dea_And_Inj_W.head()
# Out:
#                       Female_x  Female_y  From 18 to 30_x  From 18 to 30_y  \
# Region  the month
# Al-Jouf Dhu-AlQadah        0.0       3.0              6.0             10.0
#         Dhul-Hijjah        2.0      11.0              2.0             10.0
#         Jumada-Awal        0.0       2.0              0.0             10.0
#         Jumada-Thani       2.0       3.0              4.0              7.0
#         Muharram           0.0       4.0              4.0             11.0
#
#                       From 30 to 40_x  From 30 to 40_y  From 40 to 50_x  \
# Region  the month
# Al-Jouf Dhu-AlQadah               1.0              4.0              1.0
#         Dhul-Hijjah               0.0             10.0              1.0
#         Jumada-Awal               2.0              6.0              2.0
#         Jumada-Thani              3.0              9.0              0.0
#         Muharram                  1.0             11.0              2.0
#
# ...

# %%
df_dea_And_Inj_W.columns
# Out:
# Index(['Female_x', 'Female_y', 'From 18 to 30_x', 'From 18 to 30_y',
#        'From 30 to 40_x', 'From 30 to 40_y', 'From 40 to 50_x',
#        'From 40 to 50_y', 'Inside the city_x', 'Inside the city_y', 'Male_x',
#        'Male_y', 'More than 50_x', 'More than 50_y', 'Non-Saudi_x',
#        'Non-Saudi_y', 'Percent of the Inj Female', 'Percent of the Inj Male',
#        'Percent of the deaths Female', 'Percent of the deaths Male', 'Saudi_x',
#        'Saudi_y', 'Total accidents', 'Under 18_x', 'Under 18_y',
#        'outside the city_x', 'outside the city_y'],
#       dtype='object')

# %%
#حفظ الملف الدمج
df_dea_And_Inj.to_excel(r"C:\Users\a\Desktop\inj_And_dea.xlsx")
