# %%
# !pip3 install pandas

# %%
#import pandas as pd
#import seaborn as sns
#import plotly.express as px
#تم استخدام وجلب المكتبات التالية ولذلك  لعمل التالي 
import pandas as pd #   تحليل بيانات أساسية غير مرتبة بحيث ينتج عن هذا التحليل تحويل البيانات الى شكل أخر يُمكن فهمه والتعامل معه
import seaborn as sns# لإنشاء مجموعة متنوعة من الرسوم البيانية،
import numpy as np #للتعامل مع مصفوفات والعنليات الحسابية
import scipy.stats as stats# للقيام  يعملية الاحصاء 
import matplotlib.pyplot as plt # تحويل البيانات الرقمية الى رسومات
import plotly.express as px #رسم
# %matplotlib inline
import matplotlib.pyplot as plt  # كذلك لعمل رسومات بيانية

# %%
df_Inj = pd.read_excel(r'C:\Users\user 1\Desktop\Injured_1439.xlsx')
df_dth = pd.read_excel(r'C:\Users\user 1\Desktop\deaths_1439.xlsx')

# %%
df_Inj
# Out:
#          الشهر                                 المنطقة   ذكور  أناث  المجموع  \
# 0         محرم  الرياض- عدد الأشخاص المصابين حسب الجنس  364.0  29.0    393.0
# 1          صفر  الرياض- عدد الأشخاص المصابين حسب الجنس  387.0  46.0    433.0
# 2     ربيع أول  الرياض- عدد الأشخاص المصابين حسب الجنس  361.0  94.0    455.0
# 3    ربيع ثانى  الرياض- عدد الأشخاص المصابين حسب الجنس  378.0  49.0    427.0
# 4    جمادى أول  الرياض- عدد الأشخاص المصابين حسب الجنس  311.0  47.0    358.0
# ..         ...                                     ...    ...   ...      ...
# 191      شعبان                                 القريات   21.0   1.0     22.0
# 192      رمضان                                 القريات   30.0   9.0     39.0
# 193       شوال                                 القريات   15.0   1.0     16.0
# 194  ذى القعدة                                 القريات   19.0   0.0     19.0
# 195   ذى الحجة                                 القريات   20.0   2.0     22.0
#
# ...

# %%
df_dth
# Out:
#          الشهر                                         المنطقة  ذكور  أناث  \
# 0         محرم                                          الرياض  95.0   5.0
# 1          صفر                                          الرياض  93.0   5.0
# 2     ربيع أول                                          الرياض  94.0  11.0
# 3    ربيع ثانى                                          الرياض  85.0   6.0
# 4    جمادى أول                                          الرياض  95.0   1.0
# ..         ...                                             ...   ...   ...
# 204      شعبان  الـقـريات -عــد د الأشخاص المتوفين حـسب الجـنس   0.0   0.0
# 205      رمضان  الـقـريات -عــد د الأشخاص المتوفين حـسب الجـنس   5.0   3.0
# 206       شوال  الـقـريات -عــد د الأشخاص المتوفين حـسب الجـنس   1.0   1.0
# 207  ذى القعدة  الـقـريات -عــد د الأشخاص المتوفين حـسب الجـنس   4.0   0.0
# 208   ذى الحجة  الـقـريات -عــد د الأشخاص المتوفين حـسب الجـنس   6.0   2.0
#
# ...

# %%
df_Inj.info()# عرض معلومات عامة لجدول المصابين
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   الشهر         192 non-null    object
#  1   المنطقة       192 non-null    object
#  2   ذكور          192 non-null    float64
#  3   أناث          192 non-null    float64
#  4   المجموع       192 non-null    float64
#  5   داخل المدينه  192 non-null    float64
#  6   خارج المدينه  192 non-null    float64
#  7   المجموع.1     192 non-null    float64
#  8   أقل من 18     192 non-null    float64
#  9   من18 إلى 30   192 non-null    float64
#  10  من 30 على 40  192 non-null    float64
#  11  من40إلى50     192 non-null    float64
#  12  من50فأكثر     192 non-null    float64
#  13  المجموع.2     192 non-null    float64
#  14  سعودى         192 non-null    float64
#  15  غير سعودى     192 non-null    float64
#  16  المجموع.3     192 non-null    float64
# dtypes: float64(15), object(2)
# ...

# %%
df_dth.info()#عرض معلومات عامة لجدول الوفيات
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   الشهر         192 non-null    object
#  1   المنطقة       192 non-null    object
#  2   ذكور          194 non-null    float64
#  3   أناث          194 non-null    float64
#  4   المجموع       194 non-null    float64
#  5   داخل المدينه  194 non-null    float64
#  6   خارج المدينه  194 non-null    float64
#  7   المجموع.1     194 non-null    float64
#  8   أقل من 18     194 non-null    float64
#  9   من18 إلى 30   194 non-null    float64
#  10  من 30 على 40  194 non-null    float64
#  11  من40إلى50     194 non-null    float64
#  12  من50فأكثر     194 non-null    float64
#  13  المجموع.2     194 non-null    float64
#  14  سعودى         194 non-null    float64
#  15  غير سعودى     194 non-null    float64
#  16  المجموع.3     194 non-null    float64
# dtypes: float64(15), object(2)
# ...

# %%
df_Inj.shape #عدد الصفوف 194 والاعمدة 17
# Out:
# (196, 17)

# %%
df_Inj.describe()# احصائيات متعددة لجدول المصابين
# Out:
#              ذكور        أناث     المجموع  داخل المدينه  خارج المدينه  \
# count  192.000000  192.000000  192.000000    192.000000    192.000000
# mean   131.843750   25.536458  157.380208     78.005208     79.375000
# std     94.417956   22.501628  112.531816     75.757570     59.566629
# min     11.000000    0.000000   14.000000      0.000000      6.000000
# 25%     50.500000    6.000000   59.250000     16.750000     27.000000
# 50%    116.500000   18.000000  136.000000     50.000000     61.500000
# 75%    200.250000   41.000000  242.000000    111.500000    129.250000
# max    387.000000   94.000000  455.000000    295.000000    280.000000
#
#         المجموع.1   أقل من 18  من18 إلى 30  من 30 على 40   من40إلى50  \
# count  192.000000  192.000000   192.000000    192.000000  192.000000
# mean   157.380208   22.598958    48.500000     41.671875   27.260417
# std    112.531816   21.290821    32.999603     31.867554   24.580350
# ...

# %%
df_dth.describe()# احصائيات متعددة لجدول الوفيات
# Out:
#              ذكور        أناث     المجموع  داخل المدينه  خارج المدينه  \
# count  194.000000  194.000000  194.000000    194.000000    194.000000
# mean    31.056701    4.159794   35.216495     10.726804     24.489691
# std     49.065483    6.240452   53.906026     12.140482     47.835994
# min      0.000000    0.000000    0.000000      0.000000      0.000000
# 25%      9.000000    1.000000   11.250000      3.000000      7.000000
# 50%     23.500000    2.500000   26.500000      6.500000     15.000000
# 75%     39.500000    6.000000   46.000000     13.000000     34.750000
# max    632.000000   64.000000  696.000000     67.000000    641.000000
#
#         المجموع.1   أقل من 18  من18 إلى 30  من 30 على 40   من40إلى50  \
# count  194.000000  194.000000   194.000000    194.000000  194.000000
# mean    35.216495    4.948454    11.664948      8.381443    4.634021
# std     53.906026    8.768610    20.422128     12.480404    5.758083
# ...

# %%
# متوسط الوفيات للذكور خمسة اضعاف للاناث تقريباً
# تُعد الحوادث خارج المدينة ضعف الحوادث داخل المدينة تقريباً
# كلما زاد العمر سواً للذكور او للاناث كلما قلت الحوادث
# تُعد نسبة الحوادث للسعوديين ضعف نسبة الحوادث لغير السعوديين
# يُعد العمر من 18 الى 30 اعلى نسبة لوقوع الحوادث

# %%
df_Inj.isnull().sum()# ازالة الخانات الفارغة
# Out:
# الشهر           4
# المنطقة         4
# ذكور            4
# أناث            4
# المجموع         4
# داخل المدينه    4
# خارج المدينه    4
# المجموع.1       4
# أقل من 18       4
# من18 إلى 30     4
# من 30 على 40    4
# من40إلى50       4
# من50فأكثر       4
# المجموع.2       4
# سعودى           4
# غير سعودى       4
# المجموع.3       4
# dtype: int64

# %%
df_dth.isnull().sum()# ازالة الخانات الفارغة
# Out:
# الشهر           17
# المنطقة         17
# ذكور            15
# أناث            15
# المجموع         15
# داخل المدينه    15
# خارج المدينه    15
# المجموع.1       15
# أقل من 18       15
# من18 إلى 30     15
# من 30 على 40    15
# من40إلى50       15
# من50فأكثر       15
# المجموع.2       15
# سعودى           15
# غير سعودى       15
# المجموع.3       15
# dtype: int64

# %%
df_Inj.head()# يظهر اول خمس بيانات
# Out:
#        الشهر                                 المنطقة   ذكور  أناث  المجموع  \
# 0       محرم  الرياض- عدد الأشخاص المصابين حسب الجنس  364.0  29.0    393.0
# 1        صفر  الرياض- عدد الأشخاص المصابين حسب الجنس  387.0  46.0    433.0
# 2   ربيع أول  الرياض- عدد الأشخاص المصابين حسب الجنس  361.0  94.0    455.0
# 3  ربيع ثانى  الرياض- عدد الأشخاص المصابين حسب الجنس  378.0  49.0    427.0
# 4  جمادى أول  الرياض- عدد الأشخاص المصابين حسب الجنس  311.0  47.0    358.0
#
#    داخل المدينه  خارج المدينه  المجموع.1  أقل من 18  من18 إلى 30  \
# 0         291.0         102.0      393.0       66.0         97.0
# 1         276.0         157.0      433.0       44.0        117.0
# 2         284.0         171.0      455.0      115.0        124.0
# 3         295.0         132.0      427.0      132.0        119.0
# 4         262.0          96.0      358.0       61.0        111.0
#
#    من 30 على 40  من40إلى50  من50فأكثر  المجموع.2  سعودى  غير سعودى  المجموع.3
# ...

# %%
df_dth.head()# يظهر اول خمس بيانات
# Out:
#        الشهر المنطقة  ذكور  أناث  المجموع  داخل المدينه  خارج المدينه  \
# 0       محرم  الرياض  95.0   5.0    100.0          54.0          46.0
# 1        صفر  الرياض  93.0   5.0     98.0          57.0          41.0
# 2   ربيع أول  الرياض  94.0  11.0    105.0          49.0          56.0
# 3  ربيع ثانى  الرياض  85.0   6.0     91.0          46.0          45.0
# 4  جمادى أول  الرياض  95.0   1.0     96.0          51.0          45.0
#
#    المجموع.1  أقل من 18  من18 إلى 30  من 30 على 40  من40إلى50  من50فأكثر  \
# 0      100.0        9.0         38.0          27.0       12.0       14.0
# 1       98.0        9.0         38.0          25.0       14.0       12.0
# 2      105.0       22.0         13.0          35.0       24.0       11.0
# 3       91.0       29.0         22.0          19.0       13.0        8.0
# 4       96.0       15.0         35.0          26.0       12.0        8.0
#
#    المجموع.2  سعودى  غير سعودى  المجموع.3
# 0      100.0   46.0       54.0      100.0
# ...

# %%
df_Inj_clean = df_Inj.drop(["المجموع","المجموع.1","المجموع.2","المجموع.3"],axis=1)
df_Inj_clean.head() # ازاله اي عامود غير مرغوب فيه في جدول المصابين
# Out:
#        الشهر                                 المنطقة   ذكور  أناث  \
# 0       محرم  الرياض- عدد الأشخاص المصابين حسب الجنس  364.0  29.0
# 1        صفر  الرياض- عدد الأشخاص المصابين حسب الجنس  387.0  46.0
# 2   ربيع أول  الرياض- عدد الأشخاص المصابين حسب الجنس  361.0  94.0
# 3  ربيع ثانى  الرياض- عدد الأشخاص المصابين حسب الجنس  378.0  49.0
# 4  جمادى أول  الرياض- عدد الأشخاص المصابين حسب الجنس  311.0  47.0
#
#    داخل المدينه  خارج المدينه  أقل من 18  من18 إلى 30  من 30 على 40  \
# 0         291.0         102.0       66.0         97.0         126.0
# 1         276.0         157.0       44.0        117.0         145.0
# 2         284.0         171.0      115.0        124.0         108.0
# 3         295.0         132.0      132.0        119.0         103.0
# 4         262.0          96.0       61.0        111.0          89.0
#
#    من40إلى50  من50فأكثر  سعودى  غير سعودى
# 0       73.0       31.0  213.0      180.0
# 1       79.0       48.0  271.0      162.0
# ...

# %%
df_dth_clean = df_dth.drop(["المجموع","المجموع.1","المجموع.2","المجموع.3"],axis=1)
df_dth_clean.head() # ازاله اي عامود غير مرغوب فيه في جدول الوفيات
# Out:
#        الشهر المنطقة  ذكور  أناث  داخل المدينه  خارج المدينه  أقل من 18  \
# 0       محرم  الرياض  95.0   5.0          54.0          46.0        9.0
# 1        صفر  الرياض  93.0   5.0          57.0          41.0        9.0
# 2   ربيع أول  الرياض  94.0  11.0          49.0          56.0       22.0
# 3  ربيع ثانى  الرياض  85.0   6.0          46.0          45.0       29.0
# 4  جمادى أول  الرياض  95.0   1.0          51.0          45.0       15.0
#
#    من18 إلى 30  من 30 على 40  من40إلى50  من50فأكثر  سعودى  غير سعودى
# 0         38.0          27.0       12.0       14.0   46.0       54.0
# 1         38.0          25.0       14.0       12.0   46.0       52.0
# 2         13.0          35.0       24.0       11.0   59.0       46.0
# 3         22.0          19.0       13.0        8.0   49.0       42.0
# 4         35.0          26.0       12.0        8.0   52.0       44.0

# %%
df_Inj_clean.dropna(inplace = True)
df_Inj_clean # حذف الصفوف التي يوجد بها خانات فارغة في جدول المصابين
# Out:
#          الشهر                                 المنطقة   ذكور  أناث  \
# 0         محرم  الرياض- عدد الأشخاص المصابين حسب الجنس  364.0  29.0
# 1          صفر  الرياض- عدد الأشخاص المصابين حسب الجنس  387.0  46.0
# 2     ربيع أول  الرياض- عدد الأشخاص المصابين حسب الجنس  361.0  94.0
# 3    ربيع ثانى  الرياض- عدد الأشخاص المصابين حسب الجنس  378.0  49.0
# 4    جمادى أول  الرياض- عدد الأشخاص المصابين حسب الجنس  311.0  47.0
# ..         ...                                     ...    ...   ...
# 191      شعبان                                 القريات   21.0   1.0
# 192      رمضان                                 القريات   30.0   9.0
# 193       شوال                                 القريات   15.0   1.0
# 194  ذى القعدة                                 القريات   19.0   0.0
# 195   ذى الحجة                                 القريات   20.0   2.0
#
#      داخل المدينه  خارج المدينه  أقل من 18  من18 إلى 30  من 30 على 40  \
# 0           291.0         102.0       66.0         97.0         126.0
# ...

# %%
df_dth_clean.dropna(inplace = True)
df_dth_clean # حذف الصفوف التي يوجد بها خانات فارغة في جدول الوفيات
# Out:
#          الشهر                                         المنطقة  ذكور  أناث  \
# 0         محرم                                          الرياض  95.0   5.0
# 1          صفر                                          الرياض  93.0   5.0
# 2     ربيع أول                                          الرياض  94.0  11.0
# 3    ربيع ثانى                                          الرياض  85.0   6.0
# 4    جمادى أول                                          الرياض  95.0   1.0
# ..         ...                                             ...   ...   ...
# 204      شعبان  الـقـريات -عــد د الأشخاص المتوفين حـسب الجـنس   0.0   0.0
# 205      رمضان  الـقـريات -عــد د الأشخاص المتوفين حـسب الجـنس   5.0   3.0
# 206       شوال  الـقـريات -عــد د الأشخاص المتوفين حـسب الجـنس   1.0   1.0
# 207  ذى القعدة  الـقـريات -عــد د الأشخاص المتوفين حـسب الجـنس   4.0   0.0
# 208   ذى الحجة  الـقـريات -عــد د الأشخاص المتوفين حـسب الجـنس   6.0   2.0
#
# ...

# %%
df_Inj_clean['ذكور'].max()# اكبر قيمة للمصابين الذكور
# Out:
# 387.0

# %%
df_Inj_clean['ذكور'].min()# اقل قيمة للمصابين الذكور
# Out:
# 11.0

# %%
df_dth_clean['ذكور'].max() # اكبر قيمة للوفيات الذكور
# Out:
# 95.0

# %%
df_dth_clean['ذكور'].min() # اقل قيمة للوفيات الذكور
# Out:
# 0.0

# %%
df_Inj_clean.rename(columns={"أناث":"Female","ذكور":"Male","خارج المدينه":"Outside city","داخل المدينه":"Inside city",
                             "أقل من 18":"Under 18","من 18 إلى 30":"From 18 to 30","من 30 على 40":"From 30 to 40",
                             "من 40 إلى 50":"From 40 to 50","من 50 فأكثر":"More than 50","سعودى":"Saudi","غير سعودى":"not Saudi",
                             "الشهر":"the month","المنطقة":"Region"},inplace=True)
df_Inj_clean.head() #  تغيير اسماء العاواميد في جدول المصابين
# Out:
#    the month                                  Region   Male  Female  \
# 0       محرم  الرياض- عدد الأشخاص المصابين حسب الجنس  364.0    29.0
# 1        صفر  الرياض- عدد الأشخاص المصابين حسب الجنس  387.0    46.0
# 2   ربيع أول  الرياض- عدد الأشخاص المصابين حسب الجنس  361.0    94.0
# 3  ربيع ثانى  الرياض- عدد الأشخاص المصابين حسب الجنس  378.0    49.0
# 4  جمادى أول  الرياض- عدد الأشخاص المصابين حسب الجنس  311.0    47.0
#
#    Inside city  Outside city  Under 18  من18 إلى 30  From 30 to 40  من40إلى50  \
# 0        291.0         102.0      66.0         97.0          126.0       73.0
# 1        276.0         157.0      44.0        117.0          145.0       79.0
# 2        284.0         171.0     115.0        124.0          108.0       89.0
# 3        295.0         132.0     132.0        119.0          103.0       51.0
# 4        262.0          96.0      61.0        111.0           89.0       52.0
#
#    من50فأكثر  Saudi  not Saudi
# 0       31.0  213.0      180.0
# ...

# %%
df_dth_clean.rename(columns={"أناث":"Female","ذكور":"Male","خارج المدينه":"Outside city","داخل المدينه":"Inside city",
                             "أقل من 18":"Under 18","من 18 إلى 30":"From 18 to 30","من 30 على 40":"From 30 to 40",
                             "من 40 إلى 50":"From 40 to 50","من 50 فأكثر":"More than 50","سعودى":"Saudi","غير سعودى":"not Saudi",
                             "الشهر":"the month","المنطقة":"Region"},inplace=True)
df_dth_clean.head() # تغيير اسماء العاواميد في جدول الوفيات
# Out:
#    the month  Region  Male  Female  Inside city  Outside city  Under 18  \
# 0       محرم  الرياض  95.0     5.0         54.0          46.0       9.0
# 1        صفر  الرياض  93.0     5.0         57.0          41.0       9.0
# 2   ربيع أول  الرياض  94.0    11.0         49.0          56.0      22.0
# 3  ربيع ثانى  الرياض  85.0     6.0         46.0          45.0      29.0
# 4  جمادى أول  الرياض  95.0     1.0         51.0          45.0      15.0
#
#    من18 إلى 30  From 30 to 40  من40إلى50  من50فأكثر  Saudi  not Saudi
# 0         38.0           27.0       12.0       14.0   46.0       54.0
# 1         38.0           25.0       14.0       12.0   46.0       52.0
# 2         13.0           35.0       24.0       11.0   59.0       46.0
# 3         22.0           19.0       13.0        8.0   49.0       42.0
# 4         35.0           26.0       12.0        8.0   52.0       44.0

# %%
df_Inj_clean.sample(10)# عرض عدد 10 بيانات لجدول المصابين بشكل عشوائي
# Out:
#       the month                                             Region   Male  \
# 178         رجب                                            العاصمه  308.0
# 86     ربيع أول                                              نجران   38.0
# 140       رمضان                                              جازان  165.0
# 125  جمادى ثانى                                               عسير  128.0
# 18          رجب  المدينه المنوره- عــد د الأشخاص المصابين حسب ا...  215.0
# 85          صفر                                              نجران   49.0
# 151       شعبان                                                جده  257.0
# 54          رجب                                               تبوك   52.0
# 115       شعبان                                             الباحه   69.0
# 110    ربيع أول                                             الباحه   52.0
#
#      Female  Inside city  Outside city  Under 18  من18 إلى 30  From 30 to 40  \
# ...

# %%
df_dth_clean.sample(10)# عرض عدد 10 بيانات لجدول الوفيات بشكل عشوائي
# Out:
#      the month           Region  Male  Female  Inside city  Outside city  \
# 65    ذى الحجة           تـبـوك  15.0     3.0          2.0          16.0
# 129  ذى القعدة           الباحه   9.0     1.0          3.0           7.0
# 122  ربيع ثانى           الباحه   6.0     0.0          3.0           3.0
# 112        رجب           القصيم  23.0     0.0         10.0          13.0
# 42         صفر  الحدود الشماليه   5.0     0.0          2.0           3.0
# 136  جمادى أول         عـــسـير  40.0     9.0          5.0          44.0
# 2     ربيع أول           الرياض  94.0    11.0         49.0          56.0
# 121   ربيع أول           الباحه   8.0     0.0          4.0           4.0
# 11    ذى الحجة           الرياض  93.0     7.0         43.0          57.0
# 78    ذى الحجة       الجـــــوف   4.0     2.0          1.0           5.0
#
#      Under 18  من18 إلى 30  From 30 to 40  من40إلى50  من50فأكثر  Saudi  \
# 65        2.0          4.0            5.0        4.0        3.0   14.0
# ...

# %%
df_Inj_clean["Region"].unique()
# Out:
# array(['الرياض- عدد الأشخاص المصابين حسب الجنس',
#        'المدينه المنوره- عــد د الأشخاص المصابين حسب الجنس',
#        'الشرقيه- عــدد الأشخاص المصابين حسب الجنس',
#        'الحـــدو د الشماليه- عــدد الأشخاص المصابين حسب الجنس', 'تبوك',
#        'الجوف', 'حائل', 'نجران', 'القصيم', 'الباحه', 'عسير', 'جازان',
#        'جده', 'الطائف', 'العاصمه', 'القريات'], dtype=object)

# %%
df_Inj_clean["Region"].replace({'الرياض- عدد الأشخاص المصابين حسب الجنس':'Riyadh', 'القريات':'Qurayyat',
                                'المدينه المنوره- عــد د الأشخاص المصابين حسب الجنس':'Madinah',
                                'الشرقيه- عــدد الأشخاص المصابين حسب الجنس':'Eastern_Province',
                                'الحـــدو د الشماليه- عــدد الأشخاص المصابين حسب الجنس':'Northern_border',
                                'تبوك':'Tabuk', 'الجوف':'Al-Jouf','حائل':'Hail','نجران':'Najran',
                                'القصيم':'Qassim','الباحه':'Albaha','عسير':'Assir','جازان':'Jazan',
                                'جده':'Jeddah', 'الطائف':'Taif','العاصمه':'Makkah'},inplace = True)
df_Inj_clean.head()# تغيير اسماء المناطق في عامود المناطق في جدول المصابين
# Out:
#    the month  Region   Male  Female  Inside city  Outside city  Under 18  \
# 0       محرم  Riyadh  364.0    29.0        291.0         102.0      66.0
# 1        صفر  Riyadh  387.0    46.0        276.0         157.0      44.0
# 2   ربيع أول  Riyadh  361.0    94.0        284.0         171.0     115.0
# 3  ربيع ثانى  Riyadh  378.0    49.0        295.0         132.0     132.0
# 4  جمادى أول  Riyadh  311.0    47.0        262.0          96.0      61.0
#
#    من18 إلى 30  From 30 to 40  من40إلى50  من50فأكثر  Saudi  not Saudi
# 0         97.0          126.0       73.0       31.0  213.0      180.0
# 1        117.0          145.0       79.0       48.0  271.0      162.0
# 2        124.0          108.0       89.0       19.0  278.0      177.0
# 3        119.0          103.0       51.0       22.0  238.0      189.0
# 4        111.0           89.0       52.0       45.0  207.0      151.0

# %%
df_Inj_clean['the month'].replace({'محرم':'Muharram', 'صفر':'Safar','ربيع أول':'Rabi_Awal',
                                   'ربيع ثانى':'Rabie_Thani','جمادى أول':'Jumada-Awal',
                                   'جمادى ثانى':'Jumada-Thani','رجب':'Rajab','شعبان':'Shabaan',
                                   'رمضان':'Ramadan','شوال':'Shawal','ذى القعدة':'Dhu-AlQadah',
                                   'ذى الحجة':'Dhul-Hijjah'},inplace = True)
df_Inj_clean.sample(10)# تغيير اسماء عامود الشهر في جدول المصابين
# Out:
#         the month            Region   Male  Female  Inside city  Outside city  \
# 120     مــحــر م             Assir  186.0    41.0         26.0         201.0
# 25          Safar  Eastern_Province  195.0    79.0        186.0          88.0
# 190         Rajab          Qurayyat   28.0     1.0         15.0          14.0
# 151       Shabaan            Jeddah  257.0    41.0        212.0          86.0
# 187   Rabie_Thani          Qurayyat   22.0     1.0          9.0          14.0
# 185         Safar          Qurayyat   32.0     8.0         21.0          19.0
# 65   Jumada-Thani           Al-Jouf   20.0     3.0          4.0          19.0
# 154   Dhu-AlQadah            Jeddah  200.0    39.0        176.0          63.0
# 173         Safar            Makkah  180.0    44.0         98.0         126.0
# 107   Dhul-Hijjah            Qassim   69.0     9.0         56.0          22.0
#
#      Under 18  من18 إلى 30  From 30 to 40  من40إلى50  من50فأكثر  Saudi  \
# ...

# %%
df_dth.head()
# Out:
#        الشهر المنطقة  ذكور  أناث  المجموع  داخل المدينه  خارج المدينه  \
# 0       محرم  الرياض  95.0   5.0    100.0          54.0          46.0
# 1        صفر  الرياض  93.0   5.0     98.0          57.0          41.0
# 2   ربيع أول  الرياض  94.0  11.0    105.0          49.0          56.0
# 3  ربيع ثانى  الرياض  85.0   6.0     91.0          46.0          45.0
# 4  جمادى أول  الرياض  95.0   1.0     96.0          51.0          45.0
#
#    المجموع.1  أقل من 18  من18 إلى 30  من 30 على 40  من40إلى50  من50فأكثر  \
# 0      100.0        9.0         38.0          27.0       12.0       14.0
# 1       98.0        9.0         38.0          25.0       14.0       12.0
# 2      105.0       22.0         13.0          35.0       24.0       11.0
# 3       91.0       29.0         22.0          19.0       13.0        8.0
# 4       96.0       15.0         35.0          26.0       12.0        8.0
#
#    المجموع.2  سعودى  غير سعودى  المجموع.3
# 0      100.0   46.0       54.0      100.0
# ...

# %%
df_dth_clean=df_dth.drop(["المجموع.1","المجموع.2","المجموع.3","المجموع"],axis=1)
df_dth_clean.head()#حذف العواميد الخاص بالمجموع في جدول الوفيات
# Out:
#        الشهر المنطقة  ذكور  أناث  داخل المدينه  خارج المدينه  أقل من 18  \
# 0       محرم  الرياض  95.0   5.0          54.0          46.0        9.0
# 1        صفر  الرياض  93.0   5.0          57.0          41.0        9.0
# 2   ربيع أول  الرياض  94.0  11.0          49.0          56.0       22.0
# 3  ربيع ثانى  الرياض  85.0   6.0          46.0          45.0       29.0
# 4  جمادى أول  الرياض  95.0   1.0          51.0          45.0       15.0
#
#    من18 إلى 30  من 30 على 40  من40إلى50  من50فأكثر  سعودى  غير سعودى
# 0         38.0          27.0       12.0       14.0   46.0       54.0
# 1         38.0          25.0       14.0       12.0   46.0       52.0
# 2         13.0          35.0       24.0       11.0   59.0       46.0
# 3         22.0          19.0       13.0        8.0   49.0       42.0
# 4         35.0          26.0       12.0        8.0   52.0       44.0

# %%
df_dth_clean.rename(columns={"أناث":"Female","ذكور":"Male","خارج المدينه":"outside the city",
                                "داخل المدينه":"Inside the city","أقل من 18":"Under 18",
                                "من 30 على 40":"From 30 to 40","من18 إلى 30":"From 18 to 30",
                                "من40إلى50":"From 40 to 50","من50فأكثر":"More than 50",
                                "سعودى":"Saudi","غير سعودى":"Non-Saudi",
                                "الشهر":"the month","المنطقة":"Region"},inplace=True) 
df_dth_clean.head()#تغيير اسماء العواميد في جدول الوفيات
# Out:
#    the month  Region  Male  Female  Inside the city  outside the city  \
# 0       محرم  الرياض  95.0     5.0             54.0              46.0
# 1        صفر  الرياض  93.0     5.0             57.0              41.0
# 2   ربيع أول  الرياض  94.0    11.0             49.0              56.0
# 3  ربيع ثانى  الرياض  85.0     6.0             46.0              45.0
# 4  جمادى أول  الرياض  95.0     1.0             51.0              45.0
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0       9.0           38.0           27.0           12.0          14.0   46.0
# 1       9.0           38.0           25.0           14.0          12.0   46.0
# 2      22.0           13.0           35.0           24.0          11.0   59.0
# 3      29.0           22.0           19.0           13.0           8.0   49.0
# 4      15.0           35.0           26.0           12.0           8.0   52.0
#
#    Non-Saudi
# 0       54.0
# 1       52.0
# 2       46.0
# 3       42.0
# ...

# %%
df_dth_clean.sample(10)
# Out:
#       the month                                   Region   Male  Female  \
# 93         محرم                                    نجران   14.0     6.0
# 176  جمادى ثانى                                   الطائف   30.0     3.0
# 144         NaN                                      NaN  632.0    64.0
# 111  جمادى ثانى                                   القصيم   11.0     1.0
# 184        محرم  العاصمه- عدد الأشخاص المتوفين حسب الجنس   51.0     7.0
# 128        شوال                                   الباحه    7.0     3.0
# 161   ربيع ثانى                                      جده   29.0     2.0
# 60          رجب                                   تـبـوك   17.0     2.0
# 42          صفر                          الحدود الشماليه    5.0     0.0
# 119        محرم                                   الباحه   16.0     1.0
#
#      Inside the city  outside the city  Under 18  From 18 to 30  \
# 93               9.0              11.0       4.0            3.0
# ...

# %%
df_dth_clean["Region"].unique()
# Out:
# array(['الرياض', nan, 'المدينه المنوره', 'الشرقيه', 'الحدود الشماليه',
#        'تـبـوك', 'الجـــــوف', 'حـــائل', 'نجران', 'القصيم', 'الباحه',
#        'عـــسـير', 'جازان', 'جده', 'الطائف',
#        'العاصمه- عدد الأشخاص المتوفين حسب الجنس',
#        'الـقـريات -عــد د الأشخاص المتوفين حـسب الجـنس'], dtype=object)

# %%
df_dth_clean[df_dth_clean["Region"].isnull()] # يوضح الخانات الفارغة
# Out:
#     the month Region   Male  Female  Inside the city  outside the city  \
# 12        NaN    NaN    NaN     NaN              NaN               NaN
# 13        NaN    NaN    NaN     NaN              NaN               NaN
# 14        NaN    NaN    NaN     NaN              NaN               NaN
# 27        NaN    NaN    NaN     NaN              NaN               NaN
# 40        NaN    NaN    NaN     NaN              NaN               NaN
# 53        NaN    NaN    NaN     NaN              NaN               NaN
# 66        NaN    NaN    NaN     NaN              NaN               NaN
# 79        NaN    NaN    NaN     NaN              NaN               NaN
# 92        NaN    NaN    NaN     NaN              NaN               NaN
# 105       NaN    NaN    NaN     NaN              NaN               NaN
# 118       NaN    NaN    NaN     NaN              NaN               NaN
# 131       NaN    NaN   98.0    13.0             67.0              44.0
# ...

# %%
df_dth_clean.shape # يعرض عدد الصفوف والاعمدة
# Out:
# (209, 13)

# %%
df_dth_clean.dropna(inplace=True) # حذف الخانات الفارغة في الصفوف والعواميد 
df_dth_clean.shape
# Out:
# (192, 13)

# %%
df_dth_clean["Region"].replace({'الرياض':'Riyadh', 'الـقـريات -عــد د الأشخاص المتوفين حـسب الجـنس':'Qurayyat',
                                'المدينه المنوره':'Madinah',
                                'الشرقيه':'Eastern_Province',
                                'الحدود الشماليه':'Northern_border','تـبـوك':'Tabuk',
                                'الجـــــوف':'Al-Jouf','حـــائل':'Hail','نجران':'Najran','القصيم':'Qassim','الباحه':'Albaha',
                                'عـــسـير':'Assir','جازان':'Jazan','جده':'Jeddah', 'الطائف':'Taif','العاصمه- عدد الأشخاص المتوفين حسب الجنس':'Makkah'},inplace = True)


df_dth_clean.head()# تغيير اسماء المناطق
# Out:
#    the month  Region  Male  Female  Inside the city  outside the city  \
# 0       محرم  Riyadh  95.0     5.0             54.0              46.0
# 1        صفر  Riyadh  93.0     5.0             57.0              41.0
# 2   ربيع أول  Riyadh  94.0    11.0             49.0              56.0
# 3  ربيع ثانى  Riyadh  85.0     6.0             46.0              45.0
# 4  جمادى أول  Riyadh  95.0     1.0             51.0              45.0
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0       9.0           38.0           27.0           12.0          14.0   46.0
# 1       9.0           38.0           25.0           14.0          12.0   46.0
# 2      22.0           13.0           35.0           24.0          11.0   59.0
# 3      29.0           22.0           19.0           13.0           8.0   49.0
# 4      15.0           35.0           26.0           12.0           8.0   52.0
#
#    Non-Saudi
# 0       54.0
# 1       52.0
# 2       46.0
# 3       42.0
# ...

# %%
df_dth_clean['the month'].replace({'محرم':'Muharram', 'صفر':'Safar','ربيع أول':'Rabi_Awal','ربيع ثانى':'Rabie_Thani',
                               'جمادى أول':'Jumada-Awal','جمادى ثانى':'Jumada-Thani','رجب':'Rajab','شعبان':'Shabaan',
                               'رمضان':'Ramadan','شوال':'Shawal','ذى القعدة':'Dhu-AlQadah','ذى الحجة':'Dhul-Hijjah'},
                                inplace = True)
df_dth_clean.sample(10)# تغيير اسماء الاشهر
# Out:
#        the month    Region  Male  Female  Inside the city  outside the city  \
# 63        Shawal     Tabuk  24.0     4.0              3.0              25.0
# 201  Jumada-Awal  Qurayyat   4.0     0.0              1.0               3.0
# 7        Shabaan    Riyadh  66.0     9.0             28.0              47.0
# 99         Rajab    Najran  19.0     2.0              8.0              13.0
# 95     Rabi_Awal    Najran  13.0     1.0              6.0               8.0
# 140      Ramadan     Assir  54.0     6.0              5.0              55.0
# 142  Dhu-AlQadah     Assir  45.0     5.0              3.0              47.0
# 82     Rabi_Awal      Hail  28.0     1.0             14.0              15.0
# 0       Muharram    Riyadh  95.0     5.0             54.0              46.0
# 148  Rabie_Thani     Jazan  56.0     9.0              2.0              63.0
#
#      Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  \
# ...

# %%
df_dth_clean["Region"].unique()# معرفة البيانات المكررة
# Out:
# array(['Riyadh', 'Madinah', 'Eastern_Province', 'Northern_border',
#        'Tabuk', 'Al-Jouf', 'Hail', 'Najran', 'Qassim', 'Albaha', 'Assir',
#        'Jazan', 'Jeddah', 'Taif', 'Makkah', 'Qurayyat'], dtype=object)

# %%
df_dth_clean.isnull().sum()# التحقق من وجود خانات فارغة في جدول الوفيات
# Out:
# the month           0
# Region              0
# Male                0
# Female              0
# Inside the city     0
# outside the city    0
# Under 18            0
# From 18 to 30       0
# From 30 to 40       0
# From 40 to 50       0
# More than 50        0
# Saudi               0
# Non-Saudi           0
# dtype: int64

# %%
df_Inj_clean.isnull().sum()# التحقق من وجود خانات فارغة في جدول المصابين
# Out:
# the month        0
# Region           0
# Male             0
# Female           0
# Inside city      0
# Outside city     0
# Under 18         0
# من18 إلى 30      0
# From 30 to 40    0
# من40إلى50        0
# من50فأكثر        0
# Saudi            0
# not Saudi        0
# dtype: int64

# %%
df_dth_clean.head()
# Out:
#      the month  Region  Male  Female  Inside the city  outside the city  \
# 0     Muharram  Riyadh  95.0     5.0             54.0              46.0
# 1        Safar  Riyadh  93.0     5.0             57.0              41.0
# 2    Rabi_Awal  Riyadh  94.0    11.0             49.0              56.0
# 3  Rabie_Thani  Riyadh  85.0     6.0             46.0              45.0
# 4  Jumada-Awal  Riyadh  95.0     1.0             51.0              45.0
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0       9.0           38.0           27.0           12.0          14.0   46.0
# 1       9.0           38.0           25.0           14.0          12.0   46.0
# 2      22.0           13.0           35.0           24.0          11.0   59.0
# 3      29.0           22.0           19.0           13.0           8.0   49.0
# 4      15.0           35.0           26.0           12.0           8.0   52.0
#
#    Non-Saudi
# 0       54.0
# 1       52.0
# 2       46.0
# ...

# %%
 df_dth_clean_heat_map=df_dth_clean.drop(["the month","Region"],axis=1)
df_dth_clean_heat_map.head()# حذف الخانات التي لاتحتوي على ارقام
# Out:
#    Male  Female  Inside the city  outside the city  Under 18  From 18 to 30  \
# 0  95.0     5.0             54.0              46.0       9.0           38.0
# 1  93.0     5.0             57.0              41.0       9.0           38.0
# 2  94.0    11.0             49.0              56.0      22.0           13.0
# 3  85.0     6.0             46.0              45.0      29.0           22.0
# 4  95.0     1.0             51.0              45.0      15.0           35.0
#
#    From 30 to 40  From 40 to 50  More than 50  Saudi  Non-Saudi
# 0           27.0           12.0          14.0   46.0       54.0
# 1           25.0           14.0          12.0   46.0       52.0
# 2           35.0           24.0          11.0   59.0       46.0
# 3           19.0           13.0           8.0   49.0       42.0
# 4           26.0           12.0           8.0   52.0       44.0

# %%
sns.heatmap(df_dth_clean_heat_map.corr(),annot=True)#  رسم بياني يوضح علاقة البينات في بعضها البعض
# Out:
# <Axes: >

# %%
df_dth_percent=df_dth_clean
df_dth_percent["Percent of the deaths Male"]=(df_dth_clean["Male"])/(df_dth_clean["Male"]+df_dth_clean["Female"])*100
df_dth_percent["Percent of the deaths Female"]=(df_dth_clean["Female"])/(df_dth_clean["Male"]+df_dth_clean["Female"])*100
df_dth_percent.head()# حساب النسبة المئوية للوفيات من الرجال والنساء بإضافة عامودين
# Out:
#      the month  Region  Male  Female  Inside the city  outside the city  \
# 0     Muharram  Riyadh  95.0     5.0             54.0              46.0
# 1        Safar  Riyadh  93.0     5.0             57.0              41.0
# 2    Rabi_Awal  Riyadh  94.0    11.0             49.0              56.0
# 3  Rabie_Thani  Riyadh  85.0     6.0             46.0              45.0
# 4  Jumada-Awal  Riyadh  95.0     1.0             51.0              45.0
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0       9.0           38.0           27.0           12.0          14.0   46.0
# 1       9.0           38.0           25.0           14.0          12.0   46.0
# 2      22.0           13.0           35.0           24.0          11.0   59.0
# 3      29.0           22.0           19.0           13.0           8.0   49.0
# 4      15.0           35.0           26.0           12.0           8.0   52.0
#
# ...

# %%
sns.barplot(x="Percent of the deaths Male",y="Region", errorbar=None,data=df_dth_percent)
# رسم بياني لنسبة الوفيات
# Out:
# <Axes: xlabel='Percent of the deaths Male', ylabel='Region'>

# %%
# يتبين من خلال الرسم البياني بأن منطقة القصيم هي اكثر منطقة بنسبة الذكور الذين يتعرضون للوفاة

# %%
sns.pointplot(x="Percent of the deaths Female",y="Region", errorbar=None,data=df_dth_percent)
# Out:
# <Axes: xlabel='Percent of the deaths Female', ylabel='Region'>

# %%
# يتبين من خلال الرسم البياني بأن منطقة المدينة المنورة هي اكثر منطقة بنسبة الاناث الذين يتعرضون للوفاة

# %%
df_Inj_percent=df_dth_clean
df_Inj_percent["Percent of the Inj Male"]=(df_Inj_clean["Male"])/(df_Inj_clean["Male"]+df_Inj_clean["Female"])*100
df_Inj_percent["Percent of the Inj Female"]=(df_Inj_clean["Female"])/(df_Inj_clean["Male"]+df_Inj_clean["Female"])*100
df_Inj_percent.head()#حساب النسبة المئوية للحوادث من الرجال والنساء بإضافة عامودين
# Out:
#      the month  Region  Male  Female  Inside the city  outside the city  \
# 0     Muharram  Riyadh  95.0     5.0             54.0              46.0
# 1        Safar  Riyadh  93.0     5.0             57.0              41.0
# 2    Rabi_Awal  Riyadh  94.0    11.0             49.0              56.0
# 3  Rabie_Thani  Riyadh  85.0     6.0             46.0              45.0
# 4  Jumada-Awal  Riyadh  95.0     1.0             51.0              45.0
#
#    Under 18  From 18 to 30  From 30 to 40  From 40 to 50  More than 50  Saudi  \
# 0       9.0           38.0           27.0           12.0          14.0   46.0
# 1       9.0           38.0           25.0           14.0          12.0   46.0
# 2      22.0           13.0           35.0           24.0          11.0   59.0
# 3      29.0           22.0           19.0           13.0           8.0   49.0
# 4      15.0           35.0           26.0           12.0           8.0   52.0
#
# ...

# %%
sns.barplot(x="Percent of the Inj Male",y="Region", errorbar=None,data=df_Inj_percent)
# رسم بياني لنسبة الحوادث
# Out:
# <Axes: xlabel='Percent of the Inj Male', ylabel='Region'>

# %%
# يتبين من خلال الرسم البياني بأن منطقة مكة المكرمة هي اكثر منطقة بنسبة الذكور الذين يتعرضون للحوادث

# %%
sns.pointplot(x="Percent of the Inj Female",y="Region", errorbar=None,data=df_Inj_percent)
# Out:
# <Axes: xlabel='Percent of the Inj Female', ylabel='Region'>

# %%
# يتبين من خلال الرسم البياني بأن منطقة المدينة المنورة هي اكثر منطقة بنسبة الاناث الذين يتعرضون للحوادث

# %%
df_dth_clean.to_excel(r"C:\Users\user 1\Desktop\deaths_1439 - بعد التعديل.xlsx")#تم حفظ البيانات في الاكسل

# %%
df_Inj_clean.head()
# Out:
#      the month  Region   Male  Female  Inside city  Outside city  Under 18  \
# 0     Muharram  Riyadh  364.0    29.0        291.0         102.0      66.0
# 1        Safar  Riyadh  387.0    46.0        276.0         157.0      44.0
# 2    Rabi_Awal  Riyadh  361.0    94.0        284.0         171.0     115.0
# 3  Rabie_Thani  Riyadh  378.0    49.0        295.0         132.0     132.0
# 4  Jumada-Awal  Riyadh  311.0    47.0        262.0          96.0      61.0
#
#    من18 إلى 30  From 30 to 40  من40إلى50  من50فأكثر  Saudi  not Saudi
# 0         97.0          126.0       73.0       31.0  213.0      180.0
# 1        117.0          145.0       79.0       48.0  271.0      162.0
# 2        124.0          108.0       89.0       19.0  278.0      177.0
# 3        119.0          103.0       51.0       22.0  238.0      189.0
# 4        111.0           89.0       52.0       45.0  207.0      151.0

# %%
df_Inj_dth_merge=pd.merge(df_dth_clean,df_Inj_clean,on="Region",how="left")
df_Inj_dth_merge
# Out:
#       the month_x    Region  Male_x  Female_x  Inside the city  \
# 0        Muharram    Riyadh    95.0       5.0             54.0
# 1        Muharram    Riyadh    95.0       5.0             54.0
# 2        Muharram    Riyadh    95.0       5.0             54.0
# 3        Muharram    Riyadh    95.0       5.0             54.0
# 4        Muharram    Riyadh    95.0       5.0             54.0
# ...           ...       ...     ...       ...              ...
# 2299  Dhul-Hijjah  Qurayyat     6.0       2.0              0.0
# 2300  Dhul-Hijjah  Qurayyat     6.0       2.0              0.0
# 2301  Dhul-Hijjah  Qurayyat     6.0       2.0              0.0
# 2302  Dhul-Hijjah  Qurayyat     6.0       2.0              0.0
# 2303  Dhul-Hijjah  Qurayyat     6.0       2.0              0.0
#
#       outside the city  Under 18_x  From 18 to 30  From 30 to 40_x  \
# 0                 46.0         9.0           38.0             27.0
# 1                 46.0         9.0           38.0             27.0
# ...

# %%
# دمج جدول الاصابات مع جدول الوفيات

# %%
df_dth_clean.to_excel(r"C:\Users\user 1\Desktop\deaths_1439 - بعد التعديل.xlsx")# حفظ نسخة اخر في الاكسل بعد دجم الجدولين
